# %% [markdown]
# # IPL Data Exploration
#
# ## Objectives
# 1. Load and inspect the dataset structure.
# 2. Clean and standardize data (dates, teams, venues).
# 3. Perform basic exploratory analysis (matches per season, avg scores).
# 4. Save a cleaned version for downstream tasks.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os

# Add src to path
sys.path.append(os.path.abspath('../src'))
from utils import load_data, standardize_teams

# %matplotlib inline
sns.set_style('whitegrid')

# %%
# Load Data
try:
    df = load_data('../data/IPL.csv')
    print("Dataset shape:", df.shape)
    print("Columns:", df.columns.tolist())
    display(df.head())
except Exception as e:
    print(e)

# %% [markdown]
# ## 1. Structure Inspection
# Check for ball-by-ball vs match-level data.

# %%
df.info()
